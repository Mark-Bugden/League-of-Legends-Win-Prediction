# %% [markdown]
# # Win prediction for League of Legends games
# In this notebook we implement a neural network to predict the outcome of a League of Legends match based purely on the team composition. Our neural network will look roughly like this:
#
# ![Neural Network](img/nn.svg)
#
# The input is the champions on the red and blue team, as categorical variables (blue one-hot encoded as +1, red as -1), and there is a two node output predicting which team won, blue or red.

# %% [markdown]
# ### The notebook is split into the following parts:
# 1. Import packages and data
# 2. Format the data
# 3. Build the NN
# 4. Train the NN
# 5. Evaluate the NN on training and test data
# 6. Make predictions

# %% [markdown]
# ### 1. Import packages and data

# %%
"""
@author: Mark Bugden
August/September 2022

Part of a ML project in predicting win rates for League of Legends games based on team composition.
Current update available on GitHub: https://github.com/Mark-Bugden
"""

# Import necessary packages
import requests
import pandas as pd
from ratelimit import limits, sleep_and_retry
import pickle
import math
import numpy as np
from matplotlib import pyplot as plt
import os
import glob


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

# This gives us a progress bar for longer computations. 
from tqdm.notebook import tqdm
# To use it, just wrap any iterable with tqdm(iterable).
# Eg: 
# for i in tqdm(range(100)):
#     ....

# Here are the tiers and divisions
tier_list = ['DIAMOND', 'PLATINUM', 'GOLD', 'SILVER', 'BRONZE', 'IRON']
division_list = ['I', 'II', 'III', 'IV']

# Load the champion information
champion_url = 'http://ddragon.leagueoflegends.com/cdn/12.14.1/data/en_US/champion.json'
r = requests.get(champion_url)
json_data = r.json()
champion_data = json_data['data']

champions = list(champion_data.keys())

# For some reason Fiddlesticks is listed as FiddleSticks in some of the other data. To avoid problems like this, I will convert all champion names to lowercase
champions = [champ.lower() for champ in champions]


champ_to_num = {k: v for v, k in enumerate(champions)}
num_to_champ = {v: k for v, k in enumerate(champions)}

# We can get champion information by accessing the champion_data dict
# Eg:
# champion_data['Zyra']

# %%
# Load the csv file produced in the Get_Match_Data iPython notebook
rankeddf = pd.read_csv('Data collection/ranked_matches.csv', nrows = 200000) 

# Convert the champion names to lower as well to match up with our champions list.
rankeddf['championName'] = rankeddf['championName'].str.lower()

# %% [markdown]
# ### 2. Format the data

# %%
# Here are three matches
rankeddf.head(30)
# Out:
#             matchId  team    win championName      summonerName  gameMode
# 0   EUN1_3205133592  Blue  False    tahmkench     mariogrzyb321       420
# 1   EUN1_3205133592  Blue  False        elise            xBakuu       420
# 2   EUN1_3205133592  Blue  False         azir           Vecrone       420
# 3   EUN1_3205133592  Blue  False         jhin    UNfriendlyEwok       420
# 4   EUN1_3205133592  Blue  False        yuumi       metrosexual       420
# 5   EUN1_3205133592   Red   True        garen           DEMACI4       420
# 6   EUN1_3205133592   Red   True         kayn        zombieldtv       420
# 7   EUN1_3205133592   Red   True   cassiopeia   whimsical 11 19       420
# 8   EUN1_3205133592   Red   True        varus       ΞΞ ZielU ΞΞ       420
# 9   EUN1_3205133592   Red   True       xerath           savo2kk       420
# 10  EUN1_3128873118  Blue   True      drmundo            Báttya       420
# 11  EUN1_3128873118  Blue   True      warwick  Prince Of Lillie       420
# 12  EUN1_3128873118  Blue   True       graves     janosthevitez       420
# 13  EUN1_3128873118  Blue   True  missfortune             sliz5       420
# 14  EUN1_3128873118  Blue   True     nautilus          Sparrov7       420
# 15  EUN1_3128873118   Red  False        garen       beowulfe001       420
# 16  EUN1_3128873118   Red  False      xinzhao        kubajess85       420
# 17  EUN1_3128873118   Red  False     malzahar            Dimmon       420
# 18  EUN1_3128873118   Red  False       ezreal        papardeΙas       420
# 19  EUN1_3128873118   Red  False       renata          Cherryyy       420
# 20  EUN1_3189901232  Blue   True        yasuo        Onehundred       420
# 21  EUN1_3189901232  Blue   True       qiyana          bania778       420
# 22  EUN1_3189901232  Blue   True        akali    CryFockMeSatan       420
# 23  EUN1_3189901232  Blue   True        sivir  LeeJohnnySinsUwU       420
# 24  EUN1_3189901232  Blue   True         ashe        White Yuri       420
# 25  EUN1_3189901232   Red  False  mordekaiser      Jew Vanisher       420
# 26  EUN1_3189901232   Red  False           vi          rolerpro       420
# 27  EUN1_3189901232   Red  False         yone      Dr Holocaust       420
# 28  EUN1_3189901232   Red  False       ezreal   Jirka The Great       420
# 29  EUN1_3189901232   Red  False       xerath       ksmaster420       420

# %%
# One hot encode a list of champions
def onehotencodechampions(champs):
    ''' One hot encodes a list of champions.
    
    
    '''
    integer_encoded = [champ_to_num[champ] for champ in champs]
    onehot_encoded = [0] * len(champions)
    for value in integer_encoded:
        onehot_encoded[value] = 1
    return onehot_encoded

# %%
# We will now put the data into the format we will use for training and testing. This will consist of two lists - the first will be features, and the second will be labels.
# For the features list, each element of the list corresponds to a game, and that element will itself be a list of the champions in that game one-hot-encoded.
# Blue team champions being represented by +1 and red team by -1.

# For the labels list, each element will again be a game, and that element will be a one-hot encoded list of two elements. [1,0] for a blue win, and [0,1] for a red win.

matches = rankeddf['matchId'].unique().tolist()

features = []
labels = []

for match in tqdm(matches):
    blueteam = rankeddf[(rankeddf['matchId'] == match) & (rankeddf['team'] == 'Blue')]['championName'].tolist()
    redteam = rankeddf[(rankeddf['matchId'] == match) & (rankeddf['team'] == 'Red')]['championName'].tolist()
    
    blueteam = onehotencodechampions(blueteam)
    redteam = [value*-1 for value in onehotencodechampions(redteam)]
    
    features.append([sum(value) for value in zip(blueteam, redteam)])
    
    # We only need to check one champion
    if rankeddf[(rankeddf['matchId'] == match) & (rankeddf['team'] == 'Blue')].iloc[0]['win'] == True:
        labels.append([1,0])
    else:
        labels.append([0,1])
    
    
    # Since we are interested in team composition regardless of whether the team is red or blue, we can double the matches by swapping champs and winners
    # That is, champion data swaps +1 and -1, and winner swaps [1,0] and [0,1]. We then randomly select matches later for testing and training.
    
    features.append([-1*sum(value) for value in zip(blueteam, redteam)])
    if rankeddf[(rankeddf['matchId'] == match) & (rankeddf['team'] == 'Blue')].iloc[0]['win'] == True:
        labels.append([0,1])
    else:
        labels.append([1,0])
    
    

features = np.array(features)        
labels = np.array(labels)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]

# %%
# Split the data into training, validation, and test data


#train_features = features[0 :math.floor(0.7*len(matches))]
#train_labels = labels[0 : math.floor(0.7*len(matches))]

#validation_features = features[math.floor(0.7*len(matches)) : math.floor(0.9*len(matches))]
#validation_labels = labels[math.floor(0.7*len(matches)) : math.floor(0.9*len(matches))]

#test_features = features[math.floor(0.9*len(matches)) : ]
#test_labels = labels[math.floor(0.9*len(matches)) : ]



train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.3, random_state=41)

# %% [markdown]
# ### 3. Build the NN

# %%
# Define the keras model

num_hidden_layers = 8
num_neurons_per_layer = 24

model = tf.keras.Sequential()


# Some useful variables
model.num_hidden_layers = num_hidden_layers
model.num_neurons_per_layer = num_neurons_per_layer


# Input dimension is the number of champions (currently 161)
model.add(tf.keras.Input(len(champion_data)))

# Append hidden layers
for _ in range(num_hidden_layers):
    model.add(tf.keras.layers.Dropout(0.4))
    model.add(tf.keras.layers.Dense(num_neurons_per_layer,
        activation=tf.keras.activations.get('relu'),
        kernel_initializer='HeNormal', name='HiddenLayer'+str(_+1)))

# Output is two-dimensional
model.add(tf.keras.layers.Dense(2, name='Output'))


loss_fn = tf.keras.losses.BinaryCrossentropy()
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=5, verbose=True)


model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout (Dropout)           (None, 161)               0
#
#  HiddenLayer1 (Dense)        (None, 24)                3888
#
#  dropout_1 (Dropout)         (None, 24)                0
#
#  HiddenLayer2 (Dense)        (None, 24)                600
#
#  dropout_2 (Dropout)         (None, 24)                0
#
#  HiddenLayer3 (Dense)        (None, 24)                600
#
#  dropout_3 (Dropout)         (None, 24)                0
#
#  HiddenLayer4 (Dense)        (None, 24)                600
#
#  dropout_4 (Dropout)         (None, 24)                0
#
#  HiddenLayer5 (Dense)        (None, 24)                600
#
#  dropout_5 (Dropout)         (None, 24)                0
#
#  HiddenLayer6 (Dense)        (None, 24)                600
#
#  dropout_6 (Dropout)         (None, 24)                0
#
#  HiddenLayer7 (Dense)        (None, 24)                600
#
#  dropout_7 (Dropout)         (None, 24)                0
#
#  HiddenLayer8 (Dense)        (None, 24)                600
#
#  Output (Dense)              (None, 2)                 50
#
# =================================================================
# Total params: 8,138
# Trainable params: 8,138
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4. Train the network

# %%
results = model.fit(train_features, train_labels, batch_size = 100, epochs=200, validation_data=(test_features, test_labels))
# Out:
# Epoch 1/200
# 280/280 [==============================] - 3s 8ms/step - loss: 4.2022 - accuracy: 0.5013 - val_loss: 1.1541 - val_accuracy: 0.4984
# Epoch 2/200
# 280/280 [==============================] - 2s 7ms/step - loss: 1.8899 - accuracy: 0.4978 - val_loss: 0.8686 - val_accuracy: 0.5034
# Epoch 3/200
# 280/280 [==============================] - 2s 8ms/step - loss: 1.1217 - accuracy: 0.5006 - val_loss: 0.7590 - val_accuracy: 0.5032
# Epoch 4/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.8667 - accuracy: 0.4943 - val_loss: 0.7082 - val_accuracy: 0.4970
# Epoch 5/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.7950 - accuracy: 0.4995 - val_loss: 0.6973 - val_accuracy: 0.4967
# Epoch 6/200
# 280/280 [==============================] - 2s 7ms/step - loss: 0.7495 - accuracy: 0.5001 - val_loss: 0.7012 - val_accuracy: 0.4967
# Epoch 7/200
# 280/280 [==============================] - 2s 9ms/step - loss: 0.7365 - accuracy: 0.4987 - val_loss: 0.6937 - val_accuracy: 0.4967
# Epoch 8/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.7209 - accuracy: 0.5005 - val_loss: 0.6938 - val_accuracy: 0.4967
# Epoch 9/200
# 280/280 [==============================] - 3s 9ms/step - loss: 0.7148 - accuracy: 0.5002 - val_loss: 0.6935 - val_accuracy: 0.4967
# Epoch 10/200
# 280/280 [==============================] - 2s 9ms/step - loss: 0.7071 - accuracy: 0.5008 - val_loss: 0.6935 - val_accuracy: 0.4967
# Epoch 11/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.7051 - accuracy: 0.4960 - val_loss: 0.6935 - val_accuracy: 0.4966
# Epoch 12/200
# 280/280 [==============================] - 3s 9ms/step - loss: 0.7035 - accuracy: 0.5000 - val_loss: 0.6935 - val_accuracy: 0.4967
# Epoch 13/200
# 280/280 [==============================] - 2s 9ms/step - loss: 0.7002 - accuracy: 0.4981 - val_loss: 0.6933 - val_accuracy: 0.5033
# Epoch 14/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6989 - accuracy: 0.4953 - val_loss: 0.6934 - val_accuracy: 0.4967
# Epoch 15/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6981 - accuracy: 0.5003 - val_loss: 0.6942 - val_accuracy: 0.4967
# Epoch 16/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6964 - accuracy: 0.5054 - val_loss: 0.6936 - val_accuracy: 0.4967
# Epoch
200
# 280/280 [==============================] - 3s 9ms/step - loss: 0.6922 - accuracy: 0.5164 - val_loss: 0.6929 - val_accuracy: 0.5174
# Epoch 176/200
# 280/280 [==============================] - 3s 9ms/step - loss: 0.6918 - accuracy: 0.5222 - val_loss: 0.6935 - val_accuracy: 0.5037
# Epoch 177/200
# 280/280 [==============================] - 3s 9ms/step - loss: 0.6922 - accuracy: 0.5209 - val_loss: 0.6930 - val_accuracy: 0.5074
# Epoch 178/200
# 280/280 [==============================] - 3s 10ms/step - loss: 0.6920 - accuracy: 0.5184 - val_loss: 0.6934 - val_accuracy: 0.5042
# Epoch 179/200
# 280/280 [==============================] - 3s 10ms/step - loss: 0.6916 - accuracy: 0.5197 - val_loss: 0.6932 - val_accuracy: 0.5057
# Epoch 180/200
# 280/280 [==============================] - 3s 10ms/step - loss: 0.6921 - accuracy: 0.5209 - val_loss: 0.6929 - val_accuracy: 0.5106
# Epoch 181/200
# 280/280 [==============================] - 3s 10ms/step - loss: 0.6919 - accuracy: 0.5218 - val_loss: 0.6928 - val_accuracy: 0.5165
# Epoch 182/200
# 280/280 [==============================] - 2s 9ms/step - loss: 0.6919 - accuracy: 0.5230 - val_loss: 0.6928 - val_accuracy: 0.5094
# Epoch 183/200
# 280/280 [==============================] - 2s 9ms/step - loss: 0.6914 - accuracy: 0.5276 - val_loss: 0.6932 - val_accuracy: 0.5080
# Epoch 184/200
# 280/280 [==============================] - 2s 9ms/step - loss: 0.6914 - accuracy: 0.5207 - val_loss: 0.6930 - val_accuracy: 0.4967
# Epoch 185/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6919 - accuracy: 0.5185 - val_loss: 0.6929 - val_accuracy: 0.5073
# Epoch 186/200
# 280/280 [==============================] - 3s 10ms/step - loss: 0.6910 - accuracy: 0.5286 - val_loss: 0.6925 - val_accuracy: 0.5163
# Epoch 187/200
# 280/280 [==============================] - 3s 9ms/step - loss: 0.6917 - accuracy: 0.5250 - val_loss: 0.6926 - val_accuracy: 0.5163
# Epoch 188/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6915 - accuracy: 0.5240 - val_loss: 0.6929 - val_accuracy: 0.5082
# Epoch 189/200
# 280/280 [==============================] - 2s 7ms/step - loss: 0.6918 - accuracy: 0.5192 - val_loss: 0.6931 - val_accuracy: 0.5063
# Epoch 190/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6918 - accuracy: 0.5181 - val_loss: 0.6929 - val_accuracy: 0.5092
# Epoch 191/200
# 280/280 [==============================] - 3s 9ms/step - loss: 0.6917 - accuracy: 0.5304 - val_loss: 0.6930 - val_accuracy: 0.5088
# Epoch 192/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6919 - accuracy: 0.5249 - val_loss: 0.6928 - val_accuracy: 0.5106
# Epoch 193/200
# 280/280 [==============================] - 2s 9ms/step - loss: 0.6909 - accuracy: 0.5280 - val_loss: 0.6925 - val_accuracy: 0.5178
# Epoch 194/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6919 - accuracy: 0.5225 - val_loss: 0.6928 - val_accuracy: 0.5123
# Epoch 195/200
# 280/280 [==============================] - 3s 10ms/step - loss: 0.6910 - accuracy: 0.5243 - val_loss: 0.6930 - val_accuracy: 0.5092
# Epoch 196/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6907 - accuracy: 0.5281 - val_loss: 0.6929 - val_accuracy: 0.5118
# Epoch 197/200
# 280/280 [==============================] - 2s 7ms/step - loss: 0.6920 - accuracy: 0.5259 - val_loss: 0.6926 - val_accuracy: 0.5148
# Epoch 198/200
# 280/280 [==============================] - 2s 8ms/step - loss: 0.6913 - accuracy: 0.5254 - val_loss: 0.6925 - val_accuracy: 0.5168
# Epoch 199/200
# 280/280 [==============================] - 2s 9ms/step - loss: 0.6914 - accuracy: 0.5250 - val_loss: 0.6925 - val_accuracy: 0.5153
# Epoch 200/200
# 280/280 [==============================] - 2s 9ms/step - loss: 0.6913 - accuracy: 0.5263 - val_loss: 0.6923 - val_accuracy: 0.5164

# %% [markdown]
# ### 5. Evaluate the network on the training and test data

# %%
model.evaluate(train_features, train_labels, verbose=2)
# Out:
# 875/875 - 3s - loss: 0.6909 - accuracy: 0.5441 - 3s/epoch - 3ms/step
# [0.6909089684486389, 0.5441428422927856]

# %%
model.evaluate(test_features, test_labels, verbose=2)
# Out:
# 375/375 - 1s - loss: 0.6923 - accuracy: 0.5164 - 1s/epoch - 3ms/step
# [0.6923409104347229, 0.5164166688919067]

# %%
fig, axis = plt.subplots(1, 2, figsize=(20, 5))
axis[0].plot(results.history["loss"], color='r', label = 'train loss')
axis[0].plot(results.history["val_loss"], color='b', label = 'val loss')
axis[0].set_title('Loss Comparison')
axis[0].legend()
axis[1].plot(results.history["accuracy"], color='r', label = 'train accuracy')
axis[1].plot(results.history["val_accuracy"], color='b', label = 'val accuracy')
axis[1].set_title('Accuracy Comparison')
axis[1].legend()

# %% [markdown]
# ### 6. Make predictions
#
# We will now predict the winner of a random match of champions.

# %%
# Pick a random selection of champions

pred_champs = np.random.choice(161, 10, replace=False)
pred_blue_champs = pred_champs[0:5]
pred_red_champs = pred_champs[5:]

pred_blue_team = [num_to_champ[champ] for champ in pred_blue_champs]
pred_red_team = [num_to_champ[champ] for champ in pred_red_champs]

print('Blue team is: ', pred_blue_team)
print('Red team is: ', pred_red_team)
# Out:
# Blue team is:  ['lillia', 'blitzcrank', 'sejuani', 'illaoi', 'qiyana']
# Red team is:  ['ashe', 'pyke', 'hecarim', 'ryze', 'amumu']

# %%
pred_features = []

pred_blue_team_enc = onehotencodechampions(pred_blue_team)
pred_red_team_enc = [value*-1 for value in onehotencodechampions(pred_red_team)]

pred_features.append([sum(value) for value in zip(pred_blue_team_enc, pred_red_team_enc)])
pred_features = np.array(pred_features)

pred_outcome = tf.nn.softmax(model(pred_features)).numpy()

# %%
from matplotlib.image import imread

imgarrays = [imread(file) for file in glob.glob('img/Champion icons/*')]
champ_list = [champ for champ in champion_data.keys()]



fig, ax = plt.subplots(5,3)

for i in range(5):
    ax[i,0].imshow(imgarrays[champ_to_num[pred_blue_team[i]]])
    ax[i,0].set_ylabel(champ_list[champ_to_num[pred_blue_team[i]]], rotation=0, fontsize='medium', labelpad=28)
    ax[i,0].set_xticks([])
    ax[i,0].set_yticks([])
    
for i in range(5):
    ax[i,1].set_xticks([])
    ax[i,1].set_yticks([])
    ax[i,1].axis('off')

for i in range(5):
    ax[i,2].imshow(imgarrays[champ_to_num[pred_red_team[i]]])
    ax[i,2].set_ylabel(champ_list[champ_to_num[pred_red_team[i]]], rotation=0, size='medium', labelpad=28)
    ax[i,2].set_xticks([])
    ax[i,2].set_yticks([])
    
ax[0,0].set_title('Blue Team')
ax[0,2].set_title('Red Team')

plt.show()


# The predicted winner
if (pred_outcome.argmax()==0):
    print('BLUE team is the predicted winner', '\n')
    print('Blue win probability: ', pred_outcome[0][0])
    print('Red win probability: ', pred_outcome[0][1])
    
elif (pred_outcome.argmax()==1):
    print('RED team is the predicted winner', '\n')
    print('Blue win probability: ', pred_outcome[0][0])
    print('Red win probability: ', pred_outcome[0][1])
    
else:
    print('Something went wrong!', '\n')
    print('Blue win probability: ', pred_outcome[0][0])
    print('Red win probability: ', pred_outcome[0][1])
# Out:
# BLUE team is the predicted winner
#
# Blue win probability:  0.50097334
# Red win probability:  0.49902672
