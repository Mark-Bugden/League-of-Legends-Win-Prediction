# %% [markdown]
# # Web scraper to obtain World Championship matches
#
# ## Note on terminology
# In professional League of Legends, teams compete in matches against other teams (only win-lose outcomes, no draws). A match typically consists of a number of games, with the winner of a match being the team which wins a majority of the games in a match. In a tournament, the matches are often composed of just 1 game (best of 1), while the matches in the finals are typically composed of up to 5 games (best of 5).
#
# ## Workflow for scraping data
# 1. Get the matchlists for the years in which we are interested (store as tournament_matchlist_urls). Each matchlist is a URL containing the list of matches for that specific tournament and year.
# 2. Create an empty dictionary, 'matches'.
# 3. For each matchlist URL, go through the list of matches and, for each match, create a new key-value pair in the 'matches' dict. The key will be the match number, and the value will be a dictionary that consists of two key-value pairs. The first will be metadata for the match, and the second will be the match_data.
#
# metadata will be a dictionary containing {'Tournament':'', 'TeamA':'', 'TeamB':'', 'Score':'', 'Date':'', 'Patch';''}
# match_data will be a dataframe with the match data for that specific match

# %%
# Imports

import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

pd.set_option('display.max_columns', 200)

# %%
# URLs from which we will be scraping data
# Each item in this list is the matchlist URL for a different year of the World Championship
tournament_matchlist_urls = [f"https://gol.gg/tournament/tournament-matchlist/World%20Championship%2020{i}/" for i in range(14,23)]

# %%
# Print the list of urls
tournament_matchlist_urls
# Out:
# ['https://gol.gg/tournament/tournament-matchlist/World%20Championship%202014/',
#  'https://gol.gg/tournament/tournament-matchlist/World%20Championship%202015/',
#  'https://gol.gg/tournament/tournament-matchlist/World%20Championship%202016/',
#  'https://gol.gg/tournament/tournament-matchlist/World%20Championship%202017/',
#  'https://gol.gg/tournament/tournament-matchlist/World%20Championship%202018/',
#  'https://gol.gg/tournament/tournament-matchlist/World%20Championship%202019/',
#  'https://gol.gg/tournament/tournament-matchlist/World%20Championship%202020/',
#  'https://gol.gg/tournament/tournament-matchlist/World%20Championship%202021/',
#  'https://gol.gg/tournament/tournament-matchlist/World%20Championship%202022/']

# %%
matches = {}

# %%
def get_game_numbers_and_metadata(tournament_matchlist_url):
    '''
    Retrieves the list of game numbers and metadata from the matches in a given tournament.
    Input: URL of the tournament matchlist
    Returns: A pair of lists. 
    The first list being a list of game numbers corresponding to the games played in that tournament.
    The second list being a list of game metadata corresponding to the games in that tournament. 
    '''
    
    game_numbers = []
    game_data = {}
    links = []
    
    # Load the URL using requests
    # We need to use a request header to pretend we are using a popular browser or the website will (correctly) think that we are a bot.
    tournament_matchlist = requests.get(tournament_matchlist_url, headers={'User-Agent': 'Mozilla/5.0'})
    # Parse the html file using BeautifulSoup
    tournament_matchlist_soup = BeautifulSoup(tournament_matchlist.text)
    
    # Select the table in which we are interested (uses CSS selectors) 
    matchlist_table = tournament_matchlist_soup.select('table.table_list')[0]
    # Select the table rows (note that matchlist_table[0] is the column header, so we ignore that one)
    table_rows = matchlist_table.find_all('tr')
    
    # Iterate through the rows on the table
    for row in table_rows[1:]:
        
        # Select the columns in the row 
        cols = row.find_all('td')
        
        # The first column will alway contain the link, and in the link will be the game number. If the link contains the word summary, it will be a multiple game match.
        # In that case, we will need to do a little more work.
        link = cols[0].find_all('a')
        link = [l.get("href") for l in link]
        # If the match is a single game match, then compute the metadata and store the game number and metadata.
        game_number = [re.split('/', l)[3] for l in link if 'summary' not in l]
        if game_number:
            metadata = {}
            metadata['TEAMA'] = cols[1].text
            metadata['MATCH_SCORE'] = cols[2].text
            metadata['TEAMB'] = cols[3].text
            metadata['DATE'] = cols[-1].text
            metadata['PATCH'] = cols[-2].text
            game_numbers.append(game_number[0])
            game_data[game_number[0]] = metadata
        
        # If the link has 'page-summary' in it, then there may be multiple games in the match.
        link_multiples = [l for l in link if 'summary' in l]

        # In this case, getting the game numbers is a little trickier. First, we find out how many games were in the match.
        # For each link in link_multiples, retrieve the appropriate html and find out how many games are in that match.
        for link in link_multiples:
            # Load the appropriate URL
            link_data = requests.get('https://gol.gg'+link[2:], headers={'User-Agent': 'Mozilla/5.0'})
            # Parse the URL with BeautifulSoup
            link_soup = BeautifulSoup(link_data.text)
            # Count the number of times the div class 'row pb-1' appears in the html. This is the number of games played.
            n_games = len(link_soup.find_all("div", {"class":"row pb-1"}))
            # We get the other game numbers by adding 1 to the game number from link. We do this n_games-1 number of times. 
            # The metadata for each game in a multi game match is the same, but we attach it to each game number anyway.
            for i in range(n_games):
                game_number = str(int(re.split('/', link)[3]) + i)
                game_numbers.append(game_number)
                
                metadata = {}
                metadata['TEAMA'] = cols[1].text
                metadata['MATCH_SCORE'] = cols[2].text
                metadata['TEAMB'] = cols[3].text
                metadata['DATE'] = cols[-1].text
                metadata['PATCH'] = cols[-2].text
                game_data[game_number] = metadata
        # We also want to get the match metadata, namely the date, patch, teams, and score. 

        
    
    return sorted(game_numbers), game_data


def flatten(l):
    '''
    Flattens a list
    '''
    
    return [item for sublist in l for item in sublist]

# %%
# %%time
game_numbers, game_data = get_game_numbers_and_metadata(tournament_matchlist_urls[0])
# Out:
# Wall time: 2.52 s

# %%
# Out:
# {'TEAMA': 'Star Horn Royal Club',
#  'MATCH_SCORE': '1 - 3',
#  'TEAMB': 'Samsung Galaxy White',
#  'DATE': '2014-10-19',
#  'PATCH': '4.14'}

# %%
# %%time
# Get all the match numbers in all the tournaments in tournament_matchlist_urls. 
match_numbers = flatten([get_match_numbers_and_metadata(url) for url in [tournament_matchlist_urls[0]]])
# Out:
# Wall time: 2.47 s

# %%
def get_match_url(match_number):
    '''
    Takes a match number and returns the URL of the data table for that match. Very simple, very easy. 
    '''
    
    return f'https://gol.gg/game/stats/{match_number}/page-fullstats/'

# %%
# Store all the match URLs we are interested in into one list 
match_urls = [get_match_url(num) for num in match_numbers]

# %%
match_urls
# Out:
# ['https://gol.gg/game/stats/181/page-fullstats/',
#  'https://gol.gg/game/stats/182/page-fullstats/',
#  'https://gol.gg/game/stats/183/page-fullstats/',
#  'https://gol.gg/game/stats/184/page-fullstats/',
#  'https://gol.gg/game/stats/185/page-fullstats/',
#  'https://gol.gg/game/stats/186/page-fullstats/',
#  'https://gol.gg/game/stats/187/page-fullstats/',
#  'https://gol.gg/game/stats/188/page-fullstats/',
#  'https://gol.gg/game/stats/189/page-fullstats/',
#  'https://gol.gg/game/stats/190/page-fullstats/',
#  'https://gol.gg/game/stats/191/page-fullstats/',
#  'https://gol.gg/game/stats/192/page-fullstats/',
#  'https://gol.gg/game/stats/193/page-fullstats/',
#  'https://gol.gg/game/stats/194/page-fullstats/',
#  'https://gol.gg/game/stats/195/page-fullstats/',
#  'https://gol.gg/game/stats/196/page-fullstats/',
#  'https://gol.gg/game/stats/197/page-fullstats/',
#  'https://gol.gg/game/stats/198/page-fullstats/',
#  'https://gol.gg/game/stats/199/page-fullstats/',
#  'https://gol.gg/game/stats/200/page-fullstats/',
#  'https://gol.gg/game/stats/201/page-fullstats/',
#  'https://gol.gg/game/stats/202/page-fullstats/',
#  'https://gol.gg/game/stats/203/page-fullstats/',
#  'https://gol.gg/game/stats/204/page-fullstats/',
#  'https://gol.gg/game/stats/205/page-fullstats/',
#  'https://gol.gg/game/stats/206/page-fullstats/',
#  'https://gol.gg/game/stats/207/page-fullstats/',
#  'https://gol.gg/game/stats/208/page-fullstats/',
#  'https://gol.gg/game/stats/209/page-fullstats/',
#  'https://gol.gg/game/stats/210/page-fullstats/',
#  'https://gol.gg/game/stats/211/page-fullstats/',
#  'https://gol.gg/game/stats/212/page-fullstats/',
#  'https://gol.gg/game/stats/213/page-fullstats/',
#  'https://gol.gg/game/stats/214/page-fullstats/',
#  'https://gol.gg/game/stats/215/page-fullstats/',
#  'https://gol.gg/game/stats/216/page-fullstats/',
#  'https://gol.gg/game/stats/217/page-fullstats/',
#  'https://gol.gg/game/stats/218/page-fullstats/',
#  'https://gol.gg/game/stats/219/page-fullstats/',
#  'https://gol.gg/game/stats/220/page-fullstats/',
#  'https://gol.gg/game/stats/221/page-fullstats/',
#  'https://gol.gg/game/stats/222/page-fullstats/',
#  'https://gol.gg/game/stats/223/page-fullstats/',
#  'https://gol.gg/game/stats/224/page-fullstats/',
#  'https://gol.gg/game/stats/225/page-fullstats/',
#  'https://gol.gg/game/stats/226/page-fullstats/',
#  'https://gol.gg/game/stats/227/page-fullstats/',
#  'https://gol.gg/game/stats/228/page-fullstats/',
#  'https://gol.gg/game/stats/229/page-fullstats/',
#  'https://gol.gg/game/stats/230/page-fullstats/',
#  'https://gol.gg/game/stats/231/page-fullstats/',
#  'https://gol.gg/game/stats/232/page-fullstats/',
#  'https://gol.gg/game/stats/233/page-fullstats/',
#  'https://gol.gg/game/stats/234/page-fullstats/',
#  'https://gol.gg/game/stats/235/page-fullstats/',
#  'https://gol.gg/game/stats/236/page-fullstats/',
#  'https://gol.gg/game/stats/237/page-fullstats/',
#  'https://gol.gg/game/stats/238/page-fullstats/',
#  'https://gol.gg/game/stats/239/page-fullstats/',
#  'https://gol.gg/game/stats/240/page-fullstats/',
#  'https://gol.gg/game/stats/241/page-fullstats/',
#  'https://gol.gg/game/stats/242/page-fullstats/',
#  'https://gol.gg/game/stats/243/page-fullstats/',
#  'https://gol.gg/game/stats/244/page-fullstats/',
#  'https://gol.gg/game/stats/245/page-fullstats/',
#  'https://gol.gg/game/stats/246/page-fullstats/',
#  'https://gol.gg/game/stats/247/page-fullstats/',
#  'https://gol.gg/game/stats/248/page-fullstats/',
#  'https://gol.gg/game/stats/249/page-fullstats/',
#  'https://gol.gg/game/stats/252/page-fullstats/',
#  'https://gol.gg/game/stats/253/page-fullstats/',
#  'https://gol.gg/game/stats/254/page-fullstats/',
#  'https://gol.gg/game/stats/255/page-fullstats/',
#  'https://gol.gg/game/stats/256/page-fullstats/',
#  'https://gol.gg/game/stats/257/page-fullstats/',
#  'https://gol.gg/game/stats/258/page-fullstats/',
#  'https://gol.gg/game/stats/259/page-fullstats/',
#  'https://gol.gg/game/stats/260/page-fullstats/',
#  'https://gol.gg/game/stats/2179/page-fullstats/',
#  'https://gol.gg/game/stats/2180/page-fullstats/',
#  'https://gol.gg/game/stats/2181/page-fullstats/',
#  'https://gol.gg/game/stats/2182/page-fullstats/',
#  'https://gol.gg/game/stats/2183/page-fullstats/',
#  'https://gol.gg/game/stats/2185/page-fullstats/',
#  'https://gol.gg/game/stats/2187/page-fullstats/',
#  'https://gol.gg/game/stats/2188/page-fullstats/',
#  'https://gol.gg/game/stats/2189/page-fullstats/',
#  'https://gol.gg/game/stats/2190/page-fullstats/',
#  'https://gol.gg/game/stats/2191/page-fullstats/',
#  'https://gol.gg/game/stats/2192/page-fullstats/',
#  'https://gol.gg/game/stats/2193/page-fullstats/',
#  'https://gol.gg/game/stats/2194/page-fullstats/',
#  'https://gol.gg/game/stats/2195/page-fullstats/',
#  'https://gol.gg/game/stats/2196/page-fullstats/',
#  'https://gol.gg/game/stats/2197/page-fullstats/',
#  'https://gol.gg/game/stats/2198/page-fullstats/',
#  'https://gol.gg/game/stats/2199/page-fullstats/',
#  'https://gol.gg/game/stats/2200/page-fullstats/',
#  'https://gol.gg/game/stats/2201/page-fullstats/',
#  'https://gol.gg/game/stats/2202/page-fullstats/',
#  'https://gol.gg/game/stats/2203/page-fullstats/',
#  'https://gol.gg/game/stats/2204/page-fullstats/',
#  'https://gol.gg/game/stats/2205/page-fullstats/',
#  'https://gol.gg/game/stats/2206/page-fullstats/',
#  'https://gol.gg/game/stats/2207/page-fullstats/',
#  'https://gol.gg/game/stats/2208/page-fullstats/',
#  'https://gol.gg/game/stats/2209/page-fullstats/',
#  'https://gol.gg/game/stats/2210/page-fullstats/',
#  'https://gol.gg/game/stats/2211/page-fullstats/',
#  'https://gol.gg/game/stats/2212/page-fullstats/',
#  'https://gol.gg/game/stats/2213/page-fullstats/',
#  'https://gol.gg/game/stats/2214/page-fullstats/',
#  'https://gol.gg/game/stats/2215/page-fullstats/',
#  'https://gol.gg/game/stats/2216/page-fullstats/',
#  'https://gol.gg/game/stats/2217/page-fullstats/',
#  'https://gol.gg/game/stats/2218/page-fullstats/',
#  'https://gol.gg/game/stats/2219/page-fullstats/',
#  'https://gol.gg/game/stats/2220/page-fullstats/',
#  'https://gol.gg/game/stats/2221/page-fullstats/',
#  'https://gol.gg/game/stats/2222/page-fullstats/',
#  'https://gol.gg/game/stats/2223/page-fullstats/',
#  'https://gol.gg/game/stats/2224/page-fullstats/',
#  'https://gol.gg/game/stats/2225/page-fullstats/',
#  'https://gol.gg/game/stats/2226/page-fullstats/',
#  'https://gol.gg/game/stats/2227/page-fullstats/',
#  'https://gol.gg/game/stats/2228/page-fullstats/',
#  'https://gol.gg/game/stats/2229/page-fullstats/',
#  'https://gol.gg/game/stats/2230/page-fullstats/',
#  'https://gol.gg/game/stats/2231/page-fullstats/',
#  'https://gol.gg/game/stats/2232/page-fullstats/',
#  'https://gol.gg/game/stats/2233/page-fullstats/',
#  'https://gol.gg/game/stats/2235/page-fullstats/',
#  'https://gol.gg/game/stats/2236/page-fullstats/',
#  'https://gol.gg/game/stats/2237/page-fullstats/',
#  'https://gol.gg/game/stats/2240/page-fullstats/',
#  'https://gol.gg/game/stats/2241/page-fullstats/',
#  'https://gol.gg/game/stats/2242/page-fullstats/',
#  'https://gol.gg/game/stats/2245/page-fullstats/',
#  'https://gol.gg/game/stats/2246/page-fullstats/',
#  'https://gol.gg/game/stats/2247/page-fullstats/',
#  'https://gol.gg/game/stats/2248/page-fullstats/',
#  'https://gol.gg/game/stats/2249/page-fullstats/',
#  'https://gol.gg/game/stats/2250/page-fullstats/',
#  'https://gol.gg/game/stats/2251/page-fullstats/',
#  'https://gol.gg/game/stats/2254/page-fullstats/',
#  'https://gol.gg/game/stats/2255/page-fullstats/',
#  'https://gol.gg/game/stats/2256/page-fullstats/',
#  'https://gol.gg/game/stats/2257/page-fullstats/',
#  'https://gol.gg/game/stats/2258/page-fullstats/',
#  'https://gol.gg/game/stats/2259/page-fullstats/',
#  'https://gol.gg/game/stats/2260/page-fullstats/',
#  'https://gol.gg/game/stats/4625/page-fullstats/',
#  'https://gol.gg/game/stats/4626/page-fullstats/',
#  'https://gol.gg/game/stats/4627/page-fullstats/',
#  'https://gol.gg/game/stats/4628/page-fullstats/',
#  'https://gol.gg/game/stats/4629/page-fullstats/',
#  'https://gol.gg/game/stats/4630/page-fullstats/',
#  'https://gol.gg/game/stats/4631/page-fullstats/',
#  'https://gol.gg/game/stats/4632/page-fullstats/',
#  'https://gol.gg/game/stats/4633/page-fullstats/',
#  'https://gol.gg/game/stats/4634/page-fullstats/',
#  'https://gol.gg/game/stats/4635/page-fullstats/',
#  'https://gol.gg/game/stats/4636/page-fullstats/',
#  'https://gol.gg/game/stats/4637/page-fullstats/',
#  'https://gol.gg/game/stats/4638/page-fullstats/',
#  'https://gol.gg/game/stats/4639/page-fullstats/',
#  'https://gol.gg/game/stats/4640/page-fullstats/',
#  'https://gol.gg/game/stats/4641/page-fullstats/',
#  'https://gol.gg/game/stats/4642/page-fullstats/',
#  'https://gol.gg/game/stats/4643/page-fullstats/',
#  'https://gol.gg/game/stats/4644/page-fullstats/',
#  'https://gol.gg/game/stats/4645/page-fullstats/',
#  'https://gol.gg/game/stats/4646/page-fullstats/',
#  'https://gol.gg/game/stats/4647/page-fullstats/',
#  'https://gol.gg/game/stats/4648/page-fullstats/',
#  'https://gol.gg/game/stats/4649/page-fullstats/',
#  'https://gol.gg/game/stats/4650/page-fullstats/',
#  'https://gol.gg/game/stats/4651/page-fullstats/',
#  'https://gol.gg/game/stats/4652/page-fullstats/',
#  'https://gol.gg/game/stats/4653/page-fullstats/',
#  'https://gol.gg/game/stats/4654/page-fullstats/',
#  'https://gol.gg/game/stats/4655/page-fullstats/',
#  'https://gol.gg/game/stats/4656/page-fullstats/',
#  'https://gol.gg/game/stats/4657/page-fullstats/',
#  'https://gol.gg/game/stats/4658/page-fullstats/',
#  'https://gol.gg/game/stats/4659/page-fullstats/',
#  'https://gol.gg/game/stats/4660/page-fullstats/',
#  'https://gol.gg/game/stats/4661/page-fullstats/',
#  'https://gol.gg/game/stats/4662/page-fullstats/',
#  'https://gol.gg/game/stats/4663/page-fullstats/',
#  'https://gol.gg/game/stats/4664/page-fullstats/',
#  'https://gol.gg/game/stats/4665/page-fullstats/',
#  'https://gol.gg/game/stats/4666/page-fullstats/',
#  'https://gol.gg/game/stats/4667/page-fullstats/',
#  'https://gol.gg/game/stats/4668/page-fullstats/',
#  'https://gol.gg/game/stats/4669/page-fullstats/',
#  'https://gol.gg/game/stats/4670/page-fullstats/',
#  'https://gol.gg/game/stats/4671/page-fullstats/',
#  'https://gol.gg/game/stats/4672/page-fullstats/',
#  'https://gol.gg/game/stats/4673/page-fullstats/',
#  'https://gol.gg/game/stats/4674/page-fullstats/',
#  'https://gol.gg/game/stats/4675/page-fullstats/',
#  'https://gol.gg/game/stats/4676/page-fullstats/',
#  'https://gol.gg/game/stats/4677/page-fullstats/',
#  'https://gol.gg/game/stats/4680/page-fullstats/',
#  'https://gol.gg/game/stats/4681/page-fullstats/',
#  'https://gol.gg/game/stats/4682/page-fullstats/',
#  'https://gol.gg/game/stats/4683/page-fullstats/',
#  'https://gol.gg/game/stats/4685/page-fullstats/',
#  'https://gol.gg/game/stats/4686/page-fullstats/',
#  'https://gol.gg/game/stats/4687/page-fullstats/',
#  'https://gol.gg/game/stats/4688/page-fullstats/',
#  'https://gol.gg/game/stats/4690/page-fullstats/',
#  'https://gol.gg/game/stats/4691/page-fullstats/',
#  'https://gol.gg/game/stats/4692/page-fullstats/',
#  'https://gol.gg/game/stats/4693/page-fullstats/',
#  'https://gol.gg/game/stats/4694/page-fullstats/',
#  'https://gol.gg/game/stats/4695/page-fullstats/',
#  'https://gol.gg/game/stats/4696/page-fullstats/',
#  'https://gol.gg/game/stats/4697/page-fullstats/',
#  'https://gol.gg/game/stats/4698/page-fullstats/',
#  'https://gol.gg/game/stats/4699/page-fullstats/',
#  'https://gol.gg/game/stats/4700/page-fullstats/',
#  'https://gol.gg/game/stats/4701/page-fullstats/',
#  'https://gol.gg/game/stats/4702/page-fullstats/',
#  'https://gol.gg/game/stats/4703/page-fullstats/',
#  'https://gol.gg/game/stats/4704/page-fullstats/',
#  'https://gol.gg/game/stats/4705/page-fullstats/',
#  'https://gol.gg/game/stats/8995/page-fullstats/',
#  'https://gol.gg/game/stats/8996/page-fullstats/',
#  'https://gol.gg/game/stats/8997/page-fullstats/',
#  'https://gol.gg/game/stats/8998/page-fullstats/',
#  'https://gol.gg/game/stats/8999/page-fullstats/',
#  'https://gol.gg/game/stats/9000/page-fullstats/',
#  'https://gol.gg/game/stats/9001/page-fullstats/',
#  'https://gol.gg/game/stats/9002/page-fullstats/',
#  'https://gol.gg/game/stats/9003/page-fullstats/',
#  'https://gol.gg/game/stats/9004/page-fullstats/',
#  'https://gol.gg/game/stats/9005/page-fullstats/',
#  'https://gol.gg/game/stats/9006/page-fullstats/',
#  'https://gol.gg/game/stats/9007/page-fullstats/',
#  'https://gol.gg/game/stats/9008/page-fullstats/',
#  'https://gol.gg/game/stats/9009/page-fullstats/',
#  'https://gol.gg/game/stats/9010/page-fullstats/',
#  'https://gol.gg/game/stats/9011/page-fullstats/',
#  'https://gol.gg/game/stats/9012/page-fullstats/',
#  'https://gol.gg/game/stats/9013/page-fullstats/',
#  'https://gol.gg/game/stats/9014/page-fullstats/',
#  'https://gol.gg/game/stats/9015/page-fullstats/',
#  'https://gol.gg/game/stats/9016/page-fullstats/',
#  'https://gol.gg/game/stats/9017/page-fullstats/',
#  'https://gol.gg/game/stats/9018/page-fullstats/',
#  'https://gol.gg/game/stats/9019/page-fullstats/',
#  'https://gol.gg/game/stats/9020/page-fullstats/',
#  'https://gol.gg/game/stats/9021/page-fullstats/',
#  'https://gol.gg/game/stats/9022/page-fullstats/',
#  'https://gol.gg/game/stats/9023/page-fullstats/',
#  'https://gol.gg/game/stats/9024/page-fullstats/',
#  'https://gol.gg/game/stats/9025/page-fullstats/',
#  'https://gol.gg/game/stats/9026/page-fullstats/',
#  'https://gol.gg/game/stats/9027/page-fullstats/',
#  'https://gol.gg/game/stats/9028/page-fullstats/',
#  'https://gol.gg/game/stats/9029/page-fullstats/',
#  'https://gol.gg/game/stats/9030/page-fullstats/',
#  'https://gol.gg/game/stats/9031/page-fullstats/',
#  'https://gol.gg/game/stats/9032/page-fullstats/',
#  'https://gol.gg/game/stats/9033/page-fullstats/',
#  'https://gol.gg/game/stats/9034/page-fullstats/',
#  'https://gol.gg/game/stats/9035/page-fullstats/',
#  'https://gol.gg/game/stats/9036/page-fullstats/',
#  'https://gol.gg/game/stats/9037/page-fullstats/',
#  'https://gol.gg/game/stats/9038/page-fullstats/',
#  'https://gol.gg/game/stats/9039/page-fullstats/',
#  'https://gol.gg/game/stats/9040/page-fullstats/',
#  'https://gol.gg/game/stats/9041/page-fullstats/',
#  'https://gol.gg/game/stats/9042/page-fullstats/',
#  'https://gol.gg/game/stats/9043/page-fullstats/',
#  'https://gol.gg/game/stats/9044/page-fullstats/',
#  'https://gol.gg/game/stats/9045/page-fullstats/',
#  'https://gol.gg/game/stats/9046/page-fullstats/',
#  'https://gol.gg/game/stats/9047/page-fullstats/',
#  'https://gol.gg/game/stats/9048/page-fullstats/',
#  'https://gol.gg/game/stats/9051/page-fullstats/',
#  'https://gol.gg/game/stats/9052/page-fullstats/',
#  'https://gol.gg/game/stats/9053/page-fullstats/',
#  'https://gol.gg/game/stats/9054/page-fullstats/',
#  'https://gol.gg/game/stats/9055/page-fullstats/',
#  'https://gol.gg/game/stats/9056/page-fullstats/',
#  'https://gol.gg/game/stats/9057/page-fullstats/',
#  'https://gol.gg/game/stats/9058/page-fullstats/',
#  'https://gol.gg/game/stats/9059/page-fullstats/',
#  'https://gol.gg/game/stats/9061/page-fullstats/',
#  'https://gol.gg/game/stats/9062/page-fullstats/',
#  'https://gol.gg/game/stats/9063/page-fullstats/',
#  'https://gol.gg/game/stats/9064/page-fullstats/',
#  'https://gol.gg/game/stats/9065/page-fullstats/',
#  'https://gol.gg/game/stats/9066/page-fullstats/',
#  'https://gol.gg/game/stats/9067/page-fullstats/',
#  'https://gol.gg/game/stats/9068/page-fullstats/',
#  'https://gol.gg/game/stats/9069/page-fullstats/',
#  'https://gol.gg/game/stats/9070/page-fullstats/',
#  'https://gol.gg/game/stats/9071/page-fullstats/',
#  'https://gol.gg/game/stats/9072/page-fullstats/',
#  'https://gol.gg/game/stats/9073/page-fullstats/',
#  'https://gol.gg/game/stats/9074/page-fullstats/',
#  'https://gol.gg/game/stats/9075/page-fullstats/',
#  'https://gol.gg/game/stats/9076/page-fullstats/',
#  'https://gol.gg/game/stats/9077/page-fullstats/',
#  'https://gol.gg/game/stats/14453/page-fullstats/',
#  'https://gol.gg/game/stats/14454/page-fullstats/',
#  'https://gol.gg/game/stats/14455/page-fullstats/',
#  'https://gol.gg/game/stats/14456/page-fullstats/',
#  'https://gol.gg/game/stats/14457/page-fullstats/',
#  'https://gol.gg/game/stats/14458/page-fullstats/',
#  'https://gol.gg/game/stats/14459/page-fullstats/',
#  'https://gol.gg/game/stats/14460/page-fullstats/',
#  'https://gol.gg/game/stats/14461/page-fullstats/',
#  'https://gol.gg/game/stats/14462/page-fullstats/',
#  'https://gol.gg/game/stats/14463/page-fullstats/',
#  'https://gol.gg/game/stats/14464/page-fullstats/',
#  'https://gol.gg/game/stats/14465/page-fullstats/',
#  'https://gol.gg/game/stats/14466/page-fullstats/',
#  'https://gol.gg/game/stats/14467/page-fullstats/',
#  'https://gol.gg/game/stats/14468/page-fullstats/',
#  'https://gol.gg/game/stats/14469/page-fullstats/',
#  'https://gol.gg/game/stats/14470/page-fullstats/',
#  'https://gol.gg/game/stats/14471/page-fullstats/',
#  'https://gol.gg/game/stats/14472/page-fullstats/',
#  'https://gol.gg/game/stats/14473/page-fullstats/',
#  'https://gol.gg/game/stats/14474/page-fullstats/',
#  'https://gol.gg/game/stats/14475/page-fullstats/',
#  'https://gol.gg/game/stats/14476/page-fullstats/',
#  'https://gol.gg/game/stats/14477/page-fullstats/',
#  'https://gol.gg/game/stats/14478/page-fullstats/',
#  'https://gol.gg/game/stats/14479/page-fullstats/',
#  'https://gol.gg/game/stats/14480/page-fullstats/',
#  'https://gol.gg/game/stats/14481/page-fullstats/',
#  'https://gol.gg/game/stats/14482/page-fullstats/',
#  'https://gol.gg/game/stats/14483/page-fullstats/',
#  'https://gol.gg/game/stats/14484/page-fullstats/',
#  'https://gol.gg/game/stats/14485/page-fullstats/',
#  'https://gol.gg/game/stats/14486/page-fullstats/',
#  'https://gol.gg/game/stats/14487/page-fullstats/',
#  'https://gol.gg/game/stats/14488/page-fullstats/',
#  'https://gol.gg/game/stats/14489/page-fullstats/',
#  'https://gol.gg/game/stats/14490/page-fullstats/',
#  'https://gol.gg/game/stats/14491/page-fullstats/',
#  'https://gol.gg/game/stats/14492/page-fullstats/',
#  'https://gol.gg/game/stats/14493/page-fullstats/',
#  'https://gol.gg/game/stats/14494/page-fullstats/',
#  'https://gol.gg/game/stats/14495/page-fullstats/',
#  'https://gol.gg/game/stats/14496/page-fullstats/',
#  'https://gol.gg/game/stats/14497/page-fullstats/',
#  'https://gol.gg/game/stats/14498/page-fullstats/',
#  'https://gol.gg/game/stats/14499/page-fullstats/',
#  'https://gol.gg/game/stats/14500/page-fullstats/',
#  'https://gol.gg/game/stats/14501/page-fullstats/',
#  'https://gol.gg/game/stats/14502/page-fullstats/',
#  'https://gol.gg/game/stats/14503/page-fullstats/',
#  'https://gol.gg/game/stats/14504/page-fullstats/',
#  'https://gol.gg/game/stats/14505/page-fullstats/',
#  'https://gol.gg/game/stats/14506/page-fullstats/',
#  'https://gol.gg/game/stats/14507/page-fullstats/',
#  'https://gol.gg/game/stats/14508/page-fullstats/',
#  'https://gol.gg/game/stats/14509/page-fullstats/',
#  'https://gol.gg/game/stats/14510/page-fullstats/',
#  'https://gol.gg/game/stats/14511/page-fullstats/',
#  'https://gol.gg/game/stats/14512/page-fullstats/',
#  'https://gol.gg/game/stats/14513/page-fullstats/',
#  'https://gol.gg/game/stats/14514/page-fullstats/',
#  'https://gol.gg/game/stats/14515/page-fullstats/',
#  'https://gol.gg/game/stats/14516/page-fullstats/',
#  'https://gol.gg/game/stats/14519/page-fullstats/',
#  'https://gol.gg/game/stats/14520/page-fullstats/',
#  'https://gol.gg/game/stats/14521/page-fullstats/',
#  'https://gol.gg/game/stats/14522/page-fullstats/',
#  'https://gol.gg/game/stats/14523/page-fullstats/',
#  'https://gol.gg/game/stats/14524/page-fullstats/',
#  'https://gol.gg/game/stats/14525/page-fullstats/',
#  'https://gol.gg/game/stats/14528/page-fullstats/',
#  'https://gol.gg/game/stats/14529/page-fullstats/',
#  'https://gol.gg/game/stats/14530/page-fullstats/',
#  'https://gol.gg/game/stats/14531/page-fullstats/',
#  'https://gol.gg/game/stats/14532/page-fullstats/',
#  'https://gol.gg/game/stats/14533/page-fullstats/',
#  'https://gol.gg/game/stats/20415/page-fullstats/',
#  'https://gol.gg/game/stats/20416/page-fullstats/',
#  'https://gol.gg/game/stats/20417/page-fullstats/',
#  'https://gol.gg/game/stats/20418/page-fullstats/',
#  'https://gol.gg/game/stats/20419/page-fullstats/',
#  'https://gol.gg/game/stats/20420/page-fullstats/',
#  'https://gol.gg/game/stats/20421/page-fullstats/',
#  'https://gol.gg/game/stats/20422/page-fullstats/',
#  'https://gol.gg/game/stats/20423/page-fullstats/',
#  'https://gol.gg/game/stats/20424/page-fullstats/',
#  'https://gol.gg/game/stats/20425/page-fullstats/',
#  'https://gol.gg/game/stats/20426/page-fullstats/',
#  'https://gol.gg/game/stats/20427/page-fullstats/',
#  'https://gol.gg/game/stats/20428/page-fullstats/',
#  'https://gol.gg/game/stats/20429/page-fullstats/',
#  'https://gol.gg/game/stats/20430/page-fullstats/',
#  'https://gol.gg/game/stats/20431/page-fullstats/',
#  'https://gol.gg/game/stats/20432/page-fullstats/',
#  'https://gol.gg/game/stats/20433/page-fullstats/',
#  'https://gol.gg/game/stats/20434/page-fullstats/',
#  'https://gol.gg/game/stats/20435/page-fullstats/',
#  'https://gol.gg/game/stats/20436/page-fullstats/',
#  'https://gol.gg/game/stats/20437/page-fullstats/',
#  'https://gol.gg/game/stats/20438/page-fullstats/',
#  'https://gol.gg/game/stats/20439/page-fullstats/',
#  'https://gol.gg/game/stats/20440/page-fullstats/',
#  'https://gol.gg/game/stats/20441/page-fullstats/',
#  'https://gol.gg/game/stats/20442/page-fullstats/',
#  'https://gol.gg/game/stats/20443/page-fullstats/',
#  'https://gol.gg/game/stats/20444/page-fullstats/',
#  'https://gol.gg/game/stats/20445/page-fullstats/',
#  'https://gol.gg/game/stats/20446/page-fullstats/',
#  'https://gol.gg/game/stats/20447/page-fullstats/',
#  'https://gol.gg/game/stats/20448/page-fullstats/',
#  'https://gol.gg/game/stats/20449/page-fullstats/',
#  'https://gol.gg/game/stats/20450/page-fullstats/',
#  'https://gol.gg/game/stats/20451/page-fullstats/',
#  'https://gol.gg/game/stats/20452/page-fullstats/',
#  'https://gol.gg/game/stats/20453/page-fullstats/',
#  'https://gol.gg/game/stats/20454/page-fullstats/',
#  'https://gol.gg/game/stats/20455/page-fullstats/',
#  'https://gol.gg/game/stats/20456/page-fullstats/',
#  'https://gol.gg/game/stats/20457/page-fullstats/',
#  'https://gol.gg/game/stats/20458/page-fullstats/',
#  'https://gol.gg/game/stats/20459/page-fullstats/',
#  'https://gol.gg/game/stats/20460/page-fullstats/',
#  'https://gol.gg/game/stats/20461/page-fullstats/',
#  'https://gol.gg/game/stats/20462/page-fullstats/',
#  'https://gol.gg/game/stats/20463/page-fullstats/',
#  'https://gol.gg/game/stats/20464/page-fullstats/',
#  'https://gol.gg/game/stats/20465/page-fullstats/',
#  'https://gol.gg/game/stats/20466/page-fullstats/',
#  'https://gol.gg/game/stats/20467/page-fullstats/',
#  'https://gol.gg/game/stats/20468/page-fullstats/',
#  'https://gol.gg/game/stats/20470/page-fullstats/',
#  'https://gol.gg/game/stats/20471/page-fullstats/',
#  'https://gol.gg/game/stats/20472/page-fullstats/',
#  'https://gol.gg/game/stats/20473/page-fullstats/',
#  'https://gol.gg/game/stats/20475/page-fullstats/',
#  'https://gol.gg/game/stats/20476/page-fullstats/',
#  'https://gol.gg/game/stats/20477/page-fullstats/',
#  'https://gol.gg/game/stats/20478/page-fullstats/',
#  'https://gol.gg/game/stats/20480/page-fullstats/',
#  'https://gol.gg/game/stats/20481/page-fullstats/',
#  'https://gol.gg/game/stats/20482/page-fullstats/',
#  'https://gol.gg/game/stats/20483/page-fullstats/',
#  'https://gol.gg/game/stats/20484/page-fullstats/',
#  'https://gol.gg/game/stats/20485/page-fullstats/',
#  'https://gol.gg/game/stats/20486/page-fullstats/',
#  'https://gol.gg/game/stats/20487/page-fullstats/',
#  'https://gol.gg/game/stats/20489/page-fullstats/',
#  'https://gol.gg/game/stats/20490/page-fullstats/',
#  'https://gol.gg/game/stats/20491/page-fullstats/',
#  'https://gol.gg/game/stats/20492/page-fullstats/',
#  'https://gol.gg/game/stats/20493/page-fullstats/',
#  'https://gol.gg/game/stats/20494/page-fullstats/',
#  'https://gol.gg/game/stats/20495/page-fullstats/',
#  'https://gol.gg/game/stats/27045/page-fullstats/',
#  'https://gol.gg/game/stats/27046/page-fullstats/',
#  'https://gol.gg/game/stats/27047/page-fullstats/',
#  'https://gol.gg/game/stats/27048/page-fullstats/',
#  'https://gol.gg/game/stats/27049/page-fullstats/',
#  'https://gol.gg/game/stats/27050/page-fullstats/',
#  'https://gol.gg/game/stats/27051/page-fullstats/',
#  'https://gol.gg/game/stats/27052/page-fullstats/',
#  'https://gol.gg/game/stats/27053/page-fullstats/',
#  'https://gol.gg/game/stats/27054/page-fullstats/',
#  'https://gol.gg/game/stats/27055/page-fullstats/',
#  'https://gol.gg/game/stats/27056/page-fullstats/',
#  'https://gol.gg/game/stats/27057/page-fullstats/',
#  'https://gol.gg/game/stats/27058/page-fullstats/',
#  'https://gol.gg/game/stats/27059/page-fullstats/',
#  'https://gol.gg/game/stats/27060/page-fullstats/',
#  'https://gol.gg/game/stats/27061/page-fullstats/',
#  'https://gol.gg/game/stats/27062/page-fullstats/',
#  'https://gol.gg/game/stats/27063/page-fullstats/',
#  'https://gol.gg/game/stats/27064/page-fullstats/',
#  'https://gol.gg/game/stats/27065/page-fullstats/',
#  'https://gol.gg/game/stats/27066/page-fullstats/',
#  'https://gol.gg/game/stats/27067/page-fullstats/',
#  'https://gol.gg/game/stats/27068/page-fullstats/',
#  'https://gol.gg/game/stats/27069/page-fullstats/',
#  'https://gol.gg/game/stats/27070/page-fullstats/',
#  'https://gol.gg/game/stats/27071/page-fullstats/',
#  'https://gol.gg/game/stats/27072/page-fullstats/',
#  'https://gol.gg/game/stats/27073/page-fullstats/',
#  'https://gol.gg/game/stats/27074/page-fullstats/',
#  'https://gol.gg/game/stats/27075/page-fullstats/',
#  'https://gol.gg/game/stats/27076/page-fullstats/',
#  'https://gol.gg/game/stats/27077/page-fullstats/',
#  'https://gol.gg/game/stats/27078/page-fullstats/',
#  'https://gol.gg/game/stats/27079/page-fullstats/',
#  'https://gol.gg/game/stats/27080/page-fullstats/',
#  'https://gol.gg/game/stats/27081/page-fullstats/',
#  'https://gol.gg/game/stats/27082/page-fullstats/',
#  'https://gol.gg/game/stats/27083/page-fullstats/',
#  'https://gol.gg/game/stats/27084/page-fullstats/',
#  'https://gol.gg/game/stats/27085/page-fullstats/',
#  'https://gol.gg/game/stats/27086/page-fullstats/',
#  'https://gol.gg/game/stats/27087/page-fullstats/',
#  'https://gol.gg/game/stats/27088/page-fullstats/',
#  'https://gol.gg/game/stats/27089/page-fullstats/',
#  'https://gol.gg/game/stats/27090/page-fullstats/',
#  'https://gol.gg/game/stats/27091/page-fullstats/',
#  'https://gol.gg/game/stats/27092/page-fullstats/',
#  'https://gol.gg/game/stats/27106/page-fullstats/',
#  'https://gol.gg/game/stats/27107/page-fullstats/',
#  'https://gol.gg/game/stats/27108/page-fullstats/',
#  'https://gol.gg/game/stats/27109/page-fullstats/',
#  'https://gol.gg/game/stats/27110/page-fullstats/',
#  'https://gol.gg/game/stats/27111/page-fullstats/',
#  'https://gol.gg/game/stats/27112/page-fullstats/',
#  'https://gol.gg/game/stats/27113/page-fullstats/',
#  'https://gol.gg/game/stats/27114/page-fullstats/',
#  'https://gol.gg/game/stats/27115/page-fullstats/',
#  'https://gol.gg/game/stats/27117/page-fullstats/',
#  'https://gol.gg/game/stats/27118/page-fullstats/',
#  'https://gol.gg/game/stats/27119/page-fullstats/',
#  'https://gol.gg/game/stats/27122/page-fullstats/',
#  'https://gol.gg/game/stats/27123/page-fullstats/',
#  'https://gol.gg/game/stats/27124/page-fullstats/',
#  'https://gol.gg/game/stats/27125/page-fullstats/',
#  'https://gol.gg/game/stats/27126/page-fullstats/',
#  'https://gol.gg/game/stats/27127/page-fullstats/',
#  'https://gol.gg/game/stats/27128/page-fullstats/',
#  'https://gol.gg/game/stats/27130/page-fullstats/',
#  'https://gol.gg/game/stats/27131/page-fullstats/',
#  'https://gol.gg/game/stats/27132/page-fullstats/',
#  'https://gol.gg/game/stats/27133/page-fullstats/',
#  'https://gol.gg/game/stats/27191/page-fullstats/',
#  'https://gol.gg/game/stats/27192/page-fullstats/',
#  'https://gol.gg/game/stats/27193/page-fullstats/',
#  'https://gol.gg/game/stats/27194/page-fullstats/',
#  'https://gol.gg/game/stats/35231/page-fullstats/',
#  'https://gol.gg/game/stats/35232/page-fullstats/',
#  'https://gol.gg/game/stats/35233/page-fullstats/',
#  'https://gol.gg/game/stats/35234/page-fullstats/',
#  'https://gol.gg/game/stats/35235/page-fullstats/',
#  'https://gol.gg/game/stats/35236/page-fullstats/',
#  'https://gol.gg/game/stats/35237/page-fullstats/',
#  'https://gol.gg/game/stats/35238/page-fullstats/',
#  'https://gol.gg/game/stats/35239/page-fullstats/',
#  'https://gol.gg/game/stats/35240/page-fullstats/',
#  'https://gol.gg/game/stats/35241/page-fullstats/',
#  'https://gol.gg/game/stats/35242/page-fullstats/',
#  'https://gol.gg/game/stats/35243/page-fullstats/',
#  'https://gol.gg/game/stats/35244/page-fullstats/',
#  'https://gol.gg/game/stats/35245/page-fullstats/',
#  'https://gol.gg/game/stats/35246/page-fullstats/',
#  'https://gol.gg/game/stats/35247/page-fullstats/',
#  'https://gol.gg/game/stats/35248/page-fullstats/',
#  'https://gol.gg/game/stats/35249/page-fullstats/',
#  'https://gol.gg/game/stats/35250/page-fullstats/',
#  'https://gol.gg/game/stats/35251/page-fullstats/',
#  'https://gol.gg/game/stats/35252/page-fullstats/',
#  'https://gol.gg/game/stats/35253/page-fullstats/',
#  'https://gol.gg/game/stats/35254/page-fullstats/',
#  'https://gol.gg/game/stats/35255/page-fullstats/',
#  'https://gol.gg/game/stats/35256/page-fullstats/',
#  'https://gol.gg/game/stats/35257/page-fullstats/',
#  'https://gol.gg/game/stats/35258/page-fullstats/',
#  'https://gol.gg/game/stats/35259/page-fullstats/',
#  'https://gol.gg/game/stats/35260/page-fullstats/',
#  'https://gol.gg/game/stats/35261/page-fullstats/',
#  'https://gol.gg/game/stats/35262/page-fullstats/',
#  'https://gol.gg/game/stats/35263/page-fullstats/',
#  'https://gol.gg/game/stats/35264/page-fullstats/',
#  'https://gol.gg/game/stats/35265/page-fullstats/',
#  'https://gol.gg/game/stats/35266/page-fullstats/',
#  'https://gol.gg/game/stats/35267/page-fullstats/',
#  'https://gol.gg/game/stats/35268/page-fullstats/',
#  'https://gol.gg/game/stats/35269/page-fullstats/',
#  'https://gol.gg/game/stats/35270/page-fullstats/',
#  'https://gol.gg/game/stats/35271/page-fullstats/',
#  'https://gol.gg/game/stats/35272/page-fullstats/',
#  'https://gol.gg/game/stats/35273/page-fullstats/',
#  'https://gol.gg/game/stats/35274/page-fullstats/',
#  'https://gol.gg/game/stats/35275/page-fullstats/',
#  'https://gol.gg/game/stats/35276/page-fullstats/',
#  'https://gol.gg/game/stats/35277/page-fullstats/',
#  'https://gol.gg/game/stats/35278/page-fullstats/',
#  'https://gol.gg/game/stats/35326/page-fullstats/',
#  'https://gol.gg/game/stats/35327/page-fullstats/',
#  'https://gol.gg/game/stats/35328/page-fullstats/',
#  'https://gol.gg/game/stats/35329/page-fullstats/',
#  'https://gol.gg/game/stats/35330/page-fullstats/',
#  'https://gol.gg/game/stats/35331/page-fullstats/',
#  'https://gol.gg/game/stats/35332/page-fullstats/',
#  'https://gol.gg/game/stats/35333/page-fullstats/',
#  'https://gol.gg/game/stats/35334/page-fullstats/',
#  'https://gol.gg/game/stats/35337/page-fullstats/',
#  'https://gol.gg/game/stats/35338/page-fullstats/',
#  'https://gol.gg/game/stats/35339/page-fullstats/',
#  'https://gol.gg/game/stats/35340/page-fullstats/',
#  'https://gol.gg/game/stats/35341/page-fullstats/',
#  'https://gol.gg/game/stats/35342/page-fullstats/',
#  'https://gol.gg/game/stats/35343/page-fullstats/',
#  'https://gol.gg/game/stats/35344/page-fullstats/',
#  'https://gol.gg/game/stats/35347/page-fullstats/',
#  'https://gol.gg/game/stats/35348/page-fullstats/',
#  'https://gol.gg/game/stats/35349/page-fullstats/',
#  'https://gol.gg/game/stats/35370/page-fullstats/',
#  'https://gol.gg/game/stats/35371/page-fullstats/',
#  'https://gol.gg/game/stats/35372/page-fullstats/',
#  'https://gol.gg/game/stats/35373/page-fullstats/',
#  'https://gol.gg/game/stats/35374/page-fullstats/',
#  'https://gol.gg/game/stats/35375/page-fullstats/',
#  'https://gol.gg/game/stats/35376/page-fullstats/',
#  'https://gol.gg/game/stats/35377/page-fullstats/',
#  'https://gol.gg/game/stats/35378/page-fullstats/',
#  'https://gol.gg/game/stats/35379/page-fullstats/',
#  'https://gol.gg/game/stats/35402/page-fullstats/',
#  'https://gol.gg/game/stats/35403/page-fullstats/',
#  'https://gol.gg/game/stats/35404/page-fullstats/',
#  'https://gol.gg/game/stats/35405/page-fullstats/',
#  'https://gol.gg/game/stats/35406/page-fullstats/',
#  'https://gol.gg/game/stats/44337/page-fullstats/',
#  'https://gol.gg/game/stats/44338/page-fullstats/',
#  'https://gol.gg/game/stats/44339/page-fullstats/',
#  'https://gol.gg/game/stats/44340/page-fullstats/',
#  'https://gol.gg/game/stats/44341/page-fullstats/',
#  'https://gol.gg/game/stats/44342/page-fullstats/',
#  'https://gol.gg/game/stats/44343/page-fullstats/',
#  'https://gol.gg/game/stats/44344/page-fullstats/',
#  'https://gol.gg/game/stats/44345/page-fullstats/',
#  'https://gol.gg/game/stats/44346/page-fullstats/',
#  'https://gol.gg/game/stats/44347/page-fullstats/',
#  'https://gol.gg/game/stats/44348/page-fullstats/',
#  'https://gol.gg/game/stats/44349/page-fullstats/',
#  'https://gol.gg/game/stats/44350/page-fullstats/',
#  'https://gol.gg/game/stats/44351/page-fullstats/',
#  'https://gol.gg/game/stats/44352/page-fullstats/',
#  'https://gol.gg/game/stats/44353/page-fullstats/',
#  'https://gol.gg/game/stats/44354/page-fullstats/',
#  'https://gol.gg/game/stats/44355/page-fullstats/',
#  'https://gol.gg/game/stats/44356/page-fullstats/',
#  'https://gol.gg/game/stats/44357/page-fullstats/',
#  'https://gol.gg/game/stats/44358/page-fullstats/',
#  'https://gol.gg/game/stats/44359/page-fullstats/',
#  'https://gol.gg/game/stats/44360/page-fullstats/',
#  'https://gol.gg/game/stats/44361/page-fullstats/',
#  'https://gol.gg/game/stats/44362/page-fullstats/',
#  'https://gol.gg/game/stats/44363/page-fullstats/',
#  'https://gol.gg/game/stats/44364/page-fullstats/',
#  'https://gol.gg/game/stats/44365/page-fullstats/',
#  'https://gol.gg/game/stats/44366/page-fullstats/',
#  'https://gol.gg/game/stats/44367/page-fullstats/',
#  'https://gol.gg/game/stats/44368/page-fullstats/',
#  'https://gol.gg/game/stats/44369/page-fullstats/',
#  'https://gol.gg/game/stats/44370/page-fullstats/',
#  'https://gol.gg/game/stats/44371/page-fullstats/',
#  'https://gol.gg/game/stats/44372/page-fullstats/',
#  'https://gol.gg/game/stats/44373/page-fullstats/',
#  'https://gol.gg/game/stats/44374/page-fullstats/',
#  'https://gol.gg/game/stats/44375/page-fullstats/',
#  'https://gol.gg/game/stats/44376/page-fullstats/',
#  'https://gol.gg/game/stats/44377/page-fullstats/',
#  'https://gol.gg/game/stats/44378/page-fullstats/',
#  'https://gol.gg/game/stats/44379/page-fullstats/',
#  'https://gol.gg/game/stats/44380/page-fullstats/',
#  'https://gol.gg/game/stats/44381/page-fullstats/',
#  'https://gol.gg/game/stats/44382/page-fullstats/',
#  'https://gol.gg/game/stats/44383/page-fullstats/',
#  'https://gol.gg/game/stats/44384/page-fullstats/',
#  'https://gol.gg/game/stats/44385/page-fullstats/',
#  'https://gol.gg/game/stats/44386/page-fullstats/',
#  'https://gol.gg/game/stats/44387/page-fullstats/',
#  'https://gol.gg/game/stats/44388/page-fullstats/',
#  'https://gol.gg/game/stats/44389/page-fullstats/',
#  'https://gol.gg/game/stats/44390/page-fullstats/',
#  'https://gol.gg/game/stats/44393/page-fullstats/',
#  'https://gol.gg/game/stats/44394/page-fullstats/',
#  'https://gol.gg/game/stats/44395/page-fullstats/',
#  'https://gol.gg/game/stats/44398/page-fullstats/',
#  'https://gol.gg/game/stats/44399/page-fullstats/',
#  'https://gol.gg/game/stats/44400/page-fullstats/',
#  'https://gol.gg/game/stats/44401/page-fullstats/',
#  'https://gol.gg/game/stats/44402/page-fullstats/',
#  'https://gol.gg/game/stats/44403/page-fullstats/',
#  'https://gol.gg/game/stats/44404/page-fullstats/',
#  'https://gol.gg/game/stats/44405/page-fullstats/',
#  'https://gol.gg/game/stats/44406/page-fullstats/',
#  'https://gol.gg/game/stats/44407/page-fullstats/',
#  'https://gol.gg/game/stats/44408/page-fullstats/',
#  'https://gol.gg/game/stats/44409/page-fullstats/',
#  'https://gol.gg/game/stats/44410/page-fullstats/',
#  'https://gol.gg/game/stats/44411/page-fullstats/',
#  'https://gol.gg/game/stats/44413/page-fullstats/',
#  'https://gol.gg/game/stats/44414/page-fullstats/',
#  'https://gol.gg/game/stats/44415/page-fullstats/',
#  'https://gol.gg/game/stats/44416/page-fullstats/',
#  'https://gol.gg/game/stats/44417/page-fullstats/',
#  'https://gol.gg/game/stats/44418/page-fullstats/',
#  'https://gol.gg/game/stats/44419/page-fullstats/',
#  'https://gol.gg/game/stats/44420/page-fullstats/',
#  'https://gol.gg/game/stats/44421/page-fullstats/']

# %%
def get_match_df(match_url):
    '''
    Takes a match URL and returns the match data in the form of a pandas dataframe.
    '''
    
    link_data = requests.get(match_url, headers={'User-Agent': 'Mozilla/5.0'})
    # Parse the URL with BeautifulSoup
    link_soup = BeautifulSoup(link_data.text)

    stats = pd.read_html(link_data.text)[0]
    stats.set_index('Unnamed: 0',inplace=True)
    stats.index.name = None
    stats = stats.T

    stats.iloc[0].Role = 'BLUE_TOP'
    stats.iloc[1].Role = 'BLUE_JNG'
    stats.iloc[2].Role = 'BLUE_MID'
    stats.iloc[3].Role = 'BLUE_ADC'
    stats.iloc[4].Role = 'BLUE_SUP'

    stats.iloc[5].Role = 'RED_TOP'
    stats.iloc[6].Role = 'RED_JNG'
    stats.iloc[7].Role = 'RED_MID'
    stats.iloc[8].Role = 'RED_ADC'
    stats.iloc[9].Role = 'RED_SUP'
    
    stats["GOLD%"] = stats["GOLD%"].str.rstrip('%')
    stats["VS%"] = stats["VS%"].str.rstrip('%')
    stats["DMG%"] = stats["DMG%"].str.rstrip('%')
    stats["KP%"] = stats["KP%"].str.rstrip('%')


    stats.set_index('Role',inplace=True)
    
    
    # We want to convert our columns so that they have the correct data type, but there is a small problem.
    # Because of a known bug, we must first convert columns to float, then to Int64
    # See more: https://github.com/pandas-dev/pandas/issues/25472


    

    

    
    # Convert all columns except Player and KDA to float  
    float_cols = [col for col in stats.columns if (col !='Player' and col!='KDA')]
    stats = stats.astype({col:'float64' for col in float_cols})
        
    return stats

# %%
get_match_df(match_urls[-1])
# Out:
#             Player  Level  Kills  Deaths  Assists          KDA     CS  \
# Role
# BLUE_TOP      Zeus   18.0    4.0     4.0      3.0          1.8  292.0
# BLUE_JNG      Oner   17.0    2.0     2.0      7.0          4.5  256.0
# BLUE_MID     Faker   18.0    2.0     5.0      4.0          1.2  325.0
# BLUE_ADC  Gumayusi   17.0    1.0     3.0      3.0          1.3  356.0
# BLUE_SUP     Keria   13.0    1.0     5.0      3.0          0.8   35.0
# RED_TOP     kingen   18.0    6.0     3.0      6.0            4  269.0
# RED_JNG     Pyosik   16.0    5.0     4.0      8.0          3.3  192.0
# RED_MID       Zeka   18.0    3.0     2.0      9.0            6  387.0
# RED_ADC       Deft   18.0    5.0     0.0      4.0  Perfect KDA  388.0
# RED_SUP      BeryL   15.0    0.0     1.0     10.0           10   47.0
#
#           CS in Team's Jungle  CS in Enemy Jungle  CSM    Golds    GPM  GOLD%  \
# Role
# BLUE_TOP                 37.0                 NaN  6.9  15552.0  369.0   21.6
# BLUE_JNG                181.0                 NaN  6.1  14713.0  349.0   20.4
# BLUE_MID                 24.0                 NaN  7.7  15380.0  365.0   21.3
# BLUE_ADC                 32.0                 NaN  8.4  16301.0  387.0   22.6
# BLUE_SUP                  0.0                 NaN  0.8  10124.0  240.0   14.0
# RED_TOP                  27.0                 NaN  6.4  15346.0  364.0   20.5
# RED_JNG                 163.0                 NaN  4.6  13765.0  327.0   18.4
# RED_MID                  29.0                 NaN  9.2  18568.0  441.0   24.9
# RED_ADC                  37.0                 NaN  9.2  17575.0  417.0   23.5
# RED_SUP                   0.0                 NaN  1.1   9449.0  224.0   12.6
#
#           Vision Score  Wards placed  Wards destroyed  \
# Role
# BLUE_TOP          54.0          15.0             17.0
# BLUE_JNG          88.0          13.0             33.0
# BLUE_MID          53.0          21.0             10.0
# BLUE_ADC          59.0          24.0             11.0
# BLUE_SUP         123.0          75.0             17.0
# RED_TOP           57.0          15.0             18.0
# RED_JNG           68.0          21.0             17.0
# RED_MID           62.0          23.0             11.0
# RED_ADC           67.0          22.0             15.0
# RED_SUP          164.0         116.0             27.0
#
#           Control Wards Purchased  Detector Wards Placed  VSPM   WPM  VWPM  \
# Role
# BLUE_TOP                      9.0                    8.0  1.28  0.36  0.21
# BLUE_JNG                     13.0                   11.0  2.09  0.31  0.31
# BLUE_MID                     14.0                    9.0  1.26  0.50  0.33
# BLUE_ADC                      9.0                    9.0  1.40  0.57  0.21
# BLUE_SUP                     25.0                   23.0  2.92  1.78  0.59
# RED_TOP                      12.0                   12.0  1.35  0.36  0.28
# RED_JNG                      21.0                   20.0  1.61  0.50  0.50
# RED_MID                      11.0                    9.0  1.47  0.55  0.26
# RED_ADC                       6.0                    6.0  1.59  0.52  0.14
# RED_SUP                      27.0                   25.0  3.89  2.75  0.64
#
#           WCPM   VS%  Total damage to Champion  Physical Damage  Magic Damage  \
# Role
# BLUE_TOP  0.40  14.3                   27482.0           2756.0       18611.0
# BLUE_JNG  0.78  23.3                   18047.0          15492.0        1378.0
# BLUE_MID  0.24  14.1                   22454.0            474.0       21696.0
# BLUE_ADC  0.26  15.6                   25817.0          23033.0        2608.0
# BLUE_SUP  0.40  32.6                   10849.0            496.0        9308.0
# RED_TOP   0.43  13.6                   27392.0          26129.0           0.0
# RED_JNG   0.40  16.3                   12377.0           6709.0        3842.0
# RED_MID   0.26  14.8                   23385.0            267.0       22308.0
# RED_ADC   0.36  16.0                   19285.0          16676.0        1526.0
# RED_SUP   0.64  39.2                    5520.0            732.0        4166.0
#
#           True Damage    DPM  DMG%  K+A Per Minute   KP%  Solo kills  \
# Role
# BLUE_TOP       6115.0  652.0  26.3            0.17  70.0         NaN
# BLUE_JNG       1177.0  428.0  17.2            0.21  90.0         NaN
# BLUE_MID        284.0  533.0  21.5            0.14  60.0         NaN
# BLUE_ADC        176.0  613.0  24.7            0.09  40.0         NaN
# BLUE_SUP       1045.0  257.0  10.4            0.09  40.0         NaN
# RED_TOP        1263.0  650.0  31.1            0.28  63.2         2.0
# RED_JNG        1826.0  294.0  14.1            0.31  68.4         NaN
# RED_MID         810.0  555.0  26.6            0.28  63.2         NaN
# RED_ADC        1083.0  458.0  21.9            0.21  47.4         NaN
# RED_SUP         622.0  131.0   6.3            0.24  52.6         NaN
#
#           Double kills  Triple kills  Quadra kills  Penta kills  GD@15  \
# Role
# BLUE_TOP           0.0           0.0           0.0          0.0 -637.0
# BLUE_JNG           0.0           0.0           0.0          0.0  137.0
# BLUE_MID           0.0           0.0           0.0          0.0 -310.0
# BLUE_ADC           0.0           0.0           0.0          0.0  756.0
# BLUE_SUP           0.0           0.0           0.0          0.0  487.0
# RED_TOP            0.0           0.0           0.0          0.0  637.0
# RED_JNG            1.0           0.0           0.0          0.0 -137.0
# RED_MID            0.0           0.0           0.0          0.0  310.0
# RED_ADC            2.0           0.0           0.0          0.0 -756.0
# RED_SUP            0.0           0.0           0.0          0.0 -487.0
#
#           CSD@15  XPD@15  LVLD@15  Objectives Stolen  Damage dealt to turrets  \
# Role
# BLUE_TOP   -22.0 -1872.0     -2.0                0.0                   5741.0
# BLUE_JNG     9.0   368.0      0.0                0.0                   1711.0
# BLUE_MID     3.0   585.0      1.0                0.0                   2648.0
# BLUE_ADC    23.0   269.0      0.0                1.0                   7094.0
# BLUE_SUP     2.0  -315.0      0.0                0.0                   2155.0
# RED_TOP     22.0  1872.0      2.0                0.0                    966.0
# RED_JNG     -9.0  -368.0      0.0                0.0                    526.0
# RED_MID     -3.0  -585.0     -1.0                0.0                  12956.0
# RED_ADC    -23.0  -269.0      0.0                0.0                   5378.0
# RED_SUP     -2.0   315.0      0.0                0.0                    204.0
#
#           Damage dealt to buildings  Total heal  Total Heals On Teammates  \
# Role
# BLUE_TOP                     5741.0     12842.0                       0.0
# BLUE_JNG                     1711.0     16210.0                       0.0
# BLUE_MID                     2648.0      1294.0                       0.0
# BLUE_ADC                     7094.0      3036.0                       0.0
# BLUE_SUP                     2155.0       863.0                       0.0
# RED_TOP                       966.0     21444.0                       0.0
# RED_JNG                       526.0     19270.0                       0.0
# RED_MID                     12956.0      2981.0                       0.0
# RED_ADC                      5378.0      5462.0                       0.0
# RED_SUP                       204.0     14408.0                    2834.0
#
#           Damage self mitigated  Total Damage Shielded On Teammates  \
# Role
# BLUE_TOP                31989.0                                 0.0
# BLUE_JNG                30126.0                                 0.0
# BLUE_MID                22574.0                                 0.0
# BLUE_ADC                 8791.0                                 0.0
# BLUE_SUP                11043.0                              3543.0
# RED_TOP                 61310.0                                 0.0
# RED_JNG                 50572.0                                 0.0
# RED_MID                 13752.0                                 0.0
# RED_ADC                 18651.0                                 0.0
# RED_SUP                 15724.0                              1047.0
#
#           Time ccing others  Total Time CC Dealt  Total damage taken  \
# Role
# BLUE_TOP                9.0                 93.0             36130.0
# BLUE_JNG               17.0                222.0             31569.0
# BLUE_MID               21.0                473.0             20289.0
# BLUE_ADC               27.0                481.0             12202.0
# BLUE_SUP               20.0                224.0             15192.0
# RED_TOP                20.0                189.0             40472.0
# RED_JNG                19.0                223.0             40180.0
# RED_MID                15.0                312.0             15604.0
# RED_ADC                12.0                 76.0             22208.0
# RED_SUP                24.0                194.0             21875.0
#
#           Total Time Spent Dead  Consumables purchased  Items Purchased  \
# Role
# BLUE_TOP                  100.0                   11.0             31.0
# BLUE_JNG                   96.0                   12.0             32.0
# BLUE_MID                  144.0                   15.0             33.0
# BLUE_ADC                   84.0                   13.0             31.0
# BLUE_SUP                  155.0                   30.0             44.0
# RED_TOP                   150.0                   13.0             35.0
# RED_JNG                   155.0                   22.0             41.0
# RED_MID                    42.0                   14.0             33.0
# RED_ADC                     0.0                    9.0             31.0
# RED_SUP                    35.0                   30.0             47.0
#
#           Shutdown bounty collected  Shutdown bounty lost
# Role
# BLUE_TOP                        NaN                   NaN
# BLUE_JNG                        NaN                   NaN
# BLUE_MID                        NaN                   NaN
# BLUE_ADC                        NaN                   NaN
# BLUE_SUP                        NaN                   NaN
# RED_TOP                         NaN                   NaN
# RED_JNG                         NaN                   NaN
# RED_MID                         NaN                   NaN
# RED_ADC                         NaN                   NaN
# RED_SUP                         NaN                   NaN

# %%
get_df(match_urls[4]).columns

# %%
df = get_df(match_urls[-1])
df.dtypes

# %%
get_df(match_urls[-4])

# %%
col_dtypes_dict = {"Level":"Int64", 
                   "Kills":"Int64", 
                   "Deaths":"Int64", 
                   "Assists":"Int64", 
                   #'KDA':'float64',
                   "CS":"Int64",
                   "CS in Team's Jungle":"Int64",
                   "CS in Enemy Jungle":"Int64",
                   "CSM":'float64',
                   "Golds":"Int64",
                   "GPM":"Int64",
                   "GOLD%":"float64"}
